# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df13 = pd.read_csv("data/hmda_2013_pr.csv")

df13
# Out:
# C:\Users\NessaJay\AppData\Local\Temp\ipykernel_15576\2507758334.py:1: DtypeWarning: Columns (1,10,12,13,38,39,40,41,42,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   df13 = pd.read_csv("data/hmda_2013_pr.csv")
#        year  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0      2013        4043           5           1           1           3
# 1      2013       22946           3           1           1           3
# 2      2013       22946           3           4           1           1
# 3      2013       22946           3           1           1           3
# 4      2013       22946           3           4           1           1
# ...     ...         ...         ...         ...         ...         ...
# 96525  2013  7248700009           7           3           1           1
# 96526  2013  7248700009           7           4           1           1
# 96527  2013  7248700009           7           4           1           1
# ...

# %%
# replacing generic column names with useful names based of metadata files

columns = [
    "year",
    "respondent_id",
    "agency",
    "loan_type",
    "prop_type",
    "loan_purpose",
    "occupancy",
    "loan_amount",
    "preapproval",
    "action",
    "MSA/MD",
    "state",
    "county",
    "census_tract_num",
    "applicant_ethnicity",
    "co_applicant_ethnicity",
    "app_race",
    "app_race2",
    "app_race3",
    "app_race4",
    "app_race5",
    "co_app_race",
    "co_app_race2",
    "co_app_race3",
    "co_app_race4",
    "co_app_race5",
    "app_sex",
    "co_app_sex",
    "app_income",
    "purchaser_type",
    "denial_reason1",
    "denial_reason2",
    "denial_reason3",
    "rate_spread",
    "hoepa_status",
    "lien_status",
    "edit_status",
    "seq_num",
    "population",
    "minority_pop_%",
    "ffiec_med_fam_income",
    "Tract to MSA/MD Income %",
    "num_owner_occupied_units",
    "num_1_4_fam_units",
    "app_date_indicator"
]

df13.columns = columns

# %%
df13.describe(include="all")
# Out:
#            year  respondent_id        agency     loan_type     prop_type  \
# count   96530.0        96530.0  96530.000000  96530.000000  96530.000000
# unique      NaN          106.0           NaN           NaN           NaN
# top         NaN       940311.0           NaN           NaN           NaN
# freq        NaN        21716.0           NaN           NaN           NaN
# mean     2013.0            NaN      6.697980      1.581405      1.000798
# std         0.0            NaN      2.686966      0.867794      0.039016
# min      2013.0            NaN      1.000000      1.000000      1.000000
# 25%      2013.0            NaN      3.000000      1.000000      1.000000
# 50%      2013.0            NaN      9.000000      1.000000      1.000000
# 75%      2013.0            NaN      9.000000      2.000000      1.000000
# max      2013.0            NaN      9.000000      4.000000      3.000000
#
#         loan_purpose     occupancy   loan_amount   preapproval   action_type  \
# ...

# %%
df13.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96530 entries, 0 to 96529
# Data columns (total 45 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   year                      96530 non-null  int64
#  1   respondent_id             96530 non-null  object
#  2   agency                    96530 non-null  int64
#  3   loan_type                 96530 non-null  int64
#  4   prop_type                 96530 non-null  int64
#  5   loan_purpose              96530 non-null  int64
#  6   occupancy                 96530 non-null  int64
#  7   loan_amount               96530 non-null  int64
#  8   preapproval               96530 non-null  int64
#  9   action_type               96530 non-null  int64
#  10  MSA/MD                    96530 non-null  object
#  11  state                     96530 non-null  int64
#  12  county                    96530 non-null  object
#  13  census_tract_num          96530 non-null  object
# ...

# %%
# dropping columns that aren't useful in this study

df13.drop(columns=["app_race2",
                   "app_race3",
                   "app_race4",
                   "app_race5",
                   "co_app_race2",
                   "co_app_race3",
                   "co_app_race4",
                   "co_app_race5",
                   "population",
                    "minority_pop_%",
                    "ffiec_med_fam_income",
                    "Tract to MSA/MD Income %",
                    "num_owner_occupied_units",
                    "num_1_4_fam_units",
                    "app_date_indicator",
                    "state",
                    "census_tract_num"], inplace=True)

# %%
df13
# Out:
#        year respondent_id  agency  loan_type  prop_type  loan_purpose  \
# 0      2013          4043       5          1          1             3
# 1      2013         22946       3          1          1             3
# 2      2013         22946       3          4          1             1
# 3      2013         22946       3          1          1             3
# 4      2013         22946       3          4          1             1
# ...     ...           ...     ...        ...        ...           ...
# 96525  2013    7248700009       7          3          1             1
# 96526  2013    7248700009       7          4          1             1
# 96527  2013    7248700009       7          4          1             1
# 96528  2013    7248700009       7          2          1             1
# 96529  2013    77-0672274       7          2          1             3
#
#        occupancy  loan_amount  preapproval  action_type  ... app_income  \
# ...

# %%
df13["action_type"].value_counts()
# Out:
# action_type
# 1    40075
# 6    21980
# 3    20246
# 4     7638
# 5     4091
# 2     2500
# Name: count, dtype: int64
